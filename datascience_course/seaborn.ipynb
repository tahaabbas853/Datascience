# %%
#pip install seaborn

# %%
import pandas
 
# load the csv
data = pandas.read_csv("nba.csv")
import matplotlib.pyplot as plt
import seaborn as sns
 
# show first 5 column
data.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 3  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# 4   Amir Johnson  Boston Celtics      90       PF   29   9-Jun     240
#
#          College    Salary
# 0          Texas   7730337
# 1      Marquette   6796117
# 2  Georgia State   1148640
# 3            NaN   5000000
# 4            NaN  12000000

# %%
data["Position"].value_counts()
# Out:
# Position
# SG    99
# PF    97
# PG    88
# SF    84
# C     78
# Name: count, dtype: int64

# %%
data["Age"].value_counts().mode()[0]
# Out:
# 2

# %%
data["College"].describe()
# Out:
# count          364
# unique         115
# top       Kentucky
# freq            22
# Name: College, dtype: object

# %%
data.shape
# Out:
# (446, 9)

# %%
data["College"].isnull().sum()
# Out:
# 82

# %%
data.describe(include="object")
# Out:
#                  Name                  Team Position Height   College
# count             446                   446      446    446       364
# unique            446                    30        5     18       115
# top     Avery Bradley  New Orleans Pelicans       SG  9-Jun  Kentucky
# freq                1                    19       99     57        22

# %%
data.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
data['College'] = data['College'].fillna("Kentucky")

# %%
data.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 3  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# 4   Amir Johnson  Boston Celtics      90       PF   29   9-Jun     240
#
#          College    Salary
# 0          Texas   7730337
# 1      Marquette   6796117
# 2  Georgia State   1148640
# 3            NaN   5000000
# 4            NaN  12000000

# %%
sns.histplot(data["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data["Age"],bins=10,kde=False)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# plotting line plot
sns.lineplot( x=data['Age'], y=data['Weight'], hue=data['Position'], data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.lineplot(x=data['Age'],y=data['Weight'], data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.scatterplot( x=data['Age'], y=data['Weight'], hue =data["Position"])
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.boxplot( data['Age'] )
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot( x=data['Age'], y=data['Weight'])
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.violinplot(data['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=data["Position"], hue=data['Position'], legend=True, palette= 'Dark2')
plt.title('Study time (Hours)', size= 20)
plt.xlabel('Study time (Hours)', weight='bold')
plt.ylabel('count', weight='bold')
# Out:
# Text(0, 0.5, 'count')

# %%
sns.countplot(x=data["Position"])
# Out:
# <Axes: xlabel='Position', ylabel='count'>

# %%
sns.boxplot(x=data["Age"], y=data["Salary"])
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.boxplot( x=data['Age'], y=data['Weight'])
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>
